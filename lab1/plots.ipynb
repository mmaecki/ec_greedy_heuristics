# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("TSPA.csv", delimiter=';', names=['x', 'y', 'cost'])

# %%
df.head()
# Out:
#       x    y  cost
# 0  1510  353    84
# 1  3042  123   483
# 2  2145  389  1462
# 3  1030  365  1986
# 4  2125  360   145

# %%
nodes = {i: (df.x[i], df.y[i]) for i in range(len(df))}

# %%
def plot_provided_solution(solution, title, nodes):
  x_coords = [nodes[node][0] for node in solution]
  y_coords = [nodes[node][1] for node in solution]

  x_coords.append(x_coords[0])
  y_coords.append(y_coords[0])

  plt.scatter(x_coords, y_coords, c='red', marker='o', label='Selected Nodes')

  plt.plot(x_coords, y_coords, linestyle='-', marker='o', markersize=5, color='blue', label='Path')

  plt.xlabel('X Coordinate')
  plt.ylabel('Y Coordinate')
  plt.title(title)
  plt.legend()
  plt.xlim(0, 4300)
  plt.ylim(0, 2200)

  return plt

# %%
solution = [int(x) for x in input().split(" ")]
plot_provided_solution(solution, "Greedy cycle", nodes)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\matri\\anaconda3\\envs\\art\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import csv
from IPython.display import clear_output

def animate_provided_solution(title, nodes):
  for i in range(2, 101):
    solution = [int(x[0]) for x in csv.reader(open(f'animation_greedy_instance_A/{i}.csv'))]
    x_coords = [nodes[node][0] for node in solution]
    y_coords = [nodes[node][1] for node in solution]

    x_coords.append(x_coords[0])
    y_coords.append(y_coords[0])

    plt.scatter(x_coords, y_coords, c='red', marker='o', label='Selected Nodes')

    plt.plot(x_coords, y_coords, linestyle='-', marker='o', markersize=5, color='blue', label='Path')

    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')
    plt.title(title)
    plt.legend()
    plt.xlim(0, 4300)
    plt.ylim(0, 2200)
    clear_output(wait=True)
    plt.show()

animate_provided_solution("Greedy cycle", nodes)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\matri\Polibuda\ec\evolutionary_computation\lab1\plots.ipynb Cell 7 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/matri/Polibuda/ec/evolutionary_computation/lab1/plots.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a>     clear_output(wait=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/matri/Polibuda/ec/evolutionary_computation/lab1/plots.ipynb#X13sZmlsZQ%3D%3D?line=23'>24</a>     plt.show()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/matri/Polibuda/ec/evolutionary_computation/lab1/plots.ipynb#X13sZmlsZQ%3D%3D?line=25'>26</a> animate_provided_solution("Greedy cycle", nodes)
#
# c:\Users\matri\Polibuda\ec\evolutionary_computation\lab1\plots.ipynb Cell 7 line 2
# ...
